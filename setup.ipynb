# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive
# !mkdir -p git_repos
# %cd git_repos
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive
# /content/drive/MyDrive/git_repos

# %%
# !pwd
# Out:
# /content/drive/MyDrive/git_repos

# %%
# !git clone git@github.com:FlyingShuriken/WIA1007.git
# Out:
# Cloning into 'WIA1007'...
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !git clone https://github.com/FlyingShuriken/WIA1007.git
# Out:
# Cloning into 'WIA1007'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.

# %%
# %cd WIA1007
# Out:
# /content/drive/MyDrive/git_repos/WIA1007

# %%
# !ls
# Out:
# README.md  start.ipynb

# %%
# !git config --global user.email "alvinchoi0623@gmail.com"
# !git config --global user.name "flyingshuriken"

# %%
# !pwd
# Out:
# /content/drive/MyDrive/git_repos/WIA1007

# %%
# !mv "../../Colab Notebooks/setup.ipynb" "./"

# %%
# !ls
# Out:
# README.md  setup.ipynb	start.ipynb

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	setup.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)
